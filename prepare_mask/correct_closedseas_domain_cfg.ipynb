# %%
"""

Modify the domain_cfg to remove closed seas
=> not needed in the end because I could put the right stuff in the namelist

"""

# %%
import xarray as xr

# %% [markdown]
# READ DATA

# %%
inputpath_closed = '/data/cburgard/PREPARE_FORCING/PREPARE_CAVITY_MASKS/processed/'
inputpath_6ISF = '/data/cburgard/PREPARE_FORCING/PREPARE_PRESCRIBED_MELT/interim/'

# %%
domain_cfg_closed_orig = xr.open_dataset(inputpath_closed + 'eORCA1.4.3_OpenSeas_CloseAllCav_ModStraights_domain_cfg.nc')
domain_cfg_closed_6ISF = xr.open_dataset(inputpath_6ISF + 'eORCA1.4.3_OpenSeas_Open6largestISF_ModStraights_domain_cfg.nc')

# %%
bottom_level

top_level

bathy_metry

mask_opensea

mask_csundef

mask_csglo

mask_csemp

mask_csrnf

mask_csgrpglo

mask_csgrpemp

mask_csgrprnf

# %%
domain_cfg_closed_orig
# Out:
# <xarray.Dataset>
# Dimensions:           (t: 1, y: 331, x: 360, z: 75, nlines: 179)
# Dimensions without coordinates: t, y, x, z, nlines
# Data variables: (12/53)
#     e1v               (t, y, x) float64 ...
#     e2u               (t, y, x) float64 ...
#     strait_shlat      (t, y, x) float64 ...
#     nav_lon           (y, x) float32 ...
#     nav_lat           (y, x) float32 ...
#     nav_lev           (z) float32 ...
#     ...                ...
#     mask_csemp        (t, y, x) int32 ...
#     mask_csrnf        (t, y, x) int32 ...
#     mask_csgrpglo     (t, y, x) int32 ...
#     mask_csgrpemp     (t, y, x) int32 ...
#     mask_csgrprnf     (t, y, x) int32 ...
#     namelist_dom_cfg  (nlines) |S177 ...
# Attributes:
#     file_name:  domain_cfg.nc
#     TimeStamp:  13/09/2024 18:22:35 +0200
#     NCO:        netCDF Operators version 5.0.1 (Homepage = http://nco.sf.net,...
#     history:    Tue Oct  1 18:43:55 2024: ncrename -d nav_lev,z -d time_count...
